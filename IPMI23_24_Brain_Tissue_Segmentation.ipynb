# %% [markdown]
# <a href="https://colab.research.google.com/github/SuperPC328/KG_Instance_Segmentation/blob/master/IPMI23_24_Brain_Tissue_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**IPMI23-24 Lab session**
#
# ---
#
#
# #**Brain Tissue Segmentation**
# The goal of the workshop is to segment 2D brain images using a Gaussian Mixture Model, solved using the Expectation-Maximisation algorithm. The code for K-means segmentation is included for comparison. Your task is to use the code below to generate segmentations on the 4 different input images, and use different options when running the segmentation.<br>
# ###Exercise
# **You should use these data to produce brief report that includes tables and/or figures that summarises the different results.**<br>
# Please share your report with one of the teaching team for some feedback prior to leaving the session.
#
# ---
#
#
# Finally, there is an exercise to load a 3D Nifti file, slice into 2D images and then segment using one of the pipelines tested previously.

# %% [markdown]
# #Set up
# Start by importing numpy, scipy, nibabel and the Python Image Library, along with matplotlib and seaborn for plotting purposes.

# %%
import os
import sys
from collections import defaultdict
from IPython.display import display # to display images
import matplotlib.pyplot as plt
import nibabel as nib # for reading Nifti files
import numpy as np
import PIL as pl
from PIL import Image # to rotate images
import scipy as sp
import seaborn as sns
from sklearn import cluster # for running K-means

# %% [markdown]
# ##Get data
# ###Clone from Github

# %%
# !git clone https://github.com/james-cole/IPMI-teaching.git
fileLocation = "./IPMI-teaching/"
# !ls -lh IPMI-teaching/
# Out:
# Cloning into 'IPMI-teaching'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 3), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (19/19), 6.78 MiB | 16.81 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# total 6.9M
# -rw-r--r-- 1 root root  27K Feb  8 10:53 brain_bias.png
# -rw-r--r-- 1 root root  31K Feb  8 10:53 brain_noise.png
# -rw-r--r-- 1 root root  22K Feb  8 10:53 brain.png
# -rw-r--r-- 1 root root  13K Feb  8 10:53 CSF_prior.png
# -rw-r--r-- 1 root root  25K Feb  8 10:53 GM_prior.png
# -rw-r--r-- 1 root root 6.2K Feb  8 10:53 NonBrain_prior.png
# -rw-r--r-- 1 root root   90 Feb  8 10:53 README.md
# -rw-r--r-- 1 root root 6.7M Feb  8 10:53 T1w_standard.nii.gz
# -rw-r--r-- 1 root root  35K Feb  8 10:53 verynoisy.png
# -rw-r--r-- 1 root root  25K Feb  8 10:53 WM_prior.png

# %% [markdown]
# ##Define functions
# Here we will define a few different functions to make running the pipelines more straightforward.

# %% [markdown]
# ###Read images and convert to arrays

# %%
def read_file(image_file):
    imagefile = pl.Image.open(image_file)
    image_array = np.array(imagefile.getdata(), np.uint8).reshape(imagefile.size[1], imagefile.size[0])
    return image_array.astype('float32')

# %% [markdown]
# ###Convert array to image

# %%
def array_to_image(array):
    minimal_value = np.min(array)
    maximal_value = np.max(array)
    if minimal_value < 0 or maximal_value > 255:
        array = 255*(array-minimal_value)/(maximal_value-minimal_value)
    array_uint8 = array.astype('uint8')
    return pl.Image.fromarray(array_uint8, 'L') #saves as 8-bit pixels

# %% [markdown]
# ###Save array as image file

# %%
def save_file(array,filename):
    imagefile = array_to_image(array)
    imagefile.save(filename)

# %% [markdown]
# ###Display a JPEG using Pillow
# This function rotates the images 90 degrees as this is an easier way to view axial slices.

# %%
def disp_jpg(file):
    display(Image.open(fileLocation+file).rotate(90))

# %% [markdown]
# ###Markov Random Field
# Function to apply a 2D MRF, hence 4 neighbouring pixels (top, bottom, left, right).

# %%
def Umrf(pik, k):
    G = np.ones((4, 4)) - np.diag([1, 1, 1, 1])
    Umrf = np.ndarray([np.size(pik, 0), np.size(pik, 1)])
    for indexX in range(0, np.size(pik, 0)):
        for indexY in range(0, np.size(pik, 1)):
            UmrfAtIndex = 0
            for j in range(0, np.size(pik, 2)):
                Umrfj=0
                # Umrf top
                if (indexY + 1) < np.size(pik, 1):
                    Umrfj += pik[indexX, indexY + 1, j]
                # Umrf bottom
                if (indexY - 1) > -1:
                    Umrfj += pik[indexX, indexY - 1, j]
                # Umrf right
                if (indexX + 1) < np.size(pik, 0):
                    Umrfj += pik[indexX + 1, indexY, j]
                # Umrf left
                if (indexX - 1) > -1:
                    Umrfj += pik[indexX - 1, indexY, j]
                UmrfAtIndex += Umrfj * G[k, j]
            Umrf[indexX,indexY]=UmrfAtIndex;
    return Umrf

# %% [markdown]
# ##Display brain slice images
# Take a look at the input data. You'll notice the varying quality and the fact that they have been spatially normalised using image registration. This uses the disp_jpg function defined earlier.

# %%
print('brain')
disp_jpg('brain.png')
print('brain with bias field')
disp_jpg('brain_bias.png')
print('brain with noise')
disp_jpg('brain_noise.png')
print('brain with extra noise')
disp_jpg('verynoisy.png')
# Out:
# brain
# <PIL.Image.Image image mode=L size=217x181>
# brain with bias field
# <PIL.Image.Image image mode=L size=217x181>
# brain with noise
# <PIL.Image.Image image mode=L size=217x181>
# brain with extra noise
# <PIL.Image.Image image mode=L size=217x181>

# %% [markdown]
# ##Load data
# This reads in a PNG file and converts it to an array.

# %%
print("Loading data")
# Brain slices
brainData = read_file(fileLocation+'brain.png')
noiseData = read_file(fileLocation+'brain_noise.png')
verynoisyData = read_file(fileLocation+'verynoisy.png')
biasData = read_file(fileLocation+'brain_bias.png')
# Out:
# Loading data

# %% [markdown]
# ####Get image dimensions
# Check they are the expected shape.

# %%
brainData.shape
# Out:
# (181, 217)

# %% [markdown]
# ##Plot histograms of the brain images
# Compare the histograms of the different images

# %%
def plot_histogram(image_file, title):
    imgData = image_file
    plt.figure(figsize=(5,3))
    plt.hist(np.concatenate(imgData), bins=50, facecolor='firebrick', edgecolor='black', linewidth=0.1)
    plt.xlabel('Intensity')
    plt.ylabel('Count')
    plt.title(title)
    plt.tight_layout()

brains = {'brainData': brainData, 'noiseData': noiseData, 'verynoisyData' : verynoisyData, 'biasData': biasData}
for i in brains:
    plot_histogram(brains[i], i)

# %% [markdown]
# ##Density plot of brain slice intensities
# Density plots provide an alternative to histograms

# %%
def plot_density(image):
    plt.figure(figsize=(12,6))
    sns.kdeplot(np.concatenate(image), color = 'orangered', fill=True, bw_method=0.1)
    plt.tight_layout()

plot_density(brainData)

# %% [markdown]
# #K-means for brains
# Here we try using the sci-kit learn implementation of k-means to segment a brain image. **Try changing the number of clusters (k) and see how this impacts the results.**

# %%
imgData = brainData
# set number of clusters K
k = 4
np.random.seed(42)

# Reshape to a (n_sample, n_feature) array
X = imgData.reshape((-1, 1))

# define and run K-means
k_means = cluster.KMeans(n_clusters=k, n_init=10)
k_means.fit(X)
values = k_means.cluster_centers_.squeeze()
labels = k_means.labels_

# create an array from labels and values
imgData_seg = np.choose(labels, values)
imgData_seg.shape = imgData.shape

vmin = imgData.min()
vmax = imgData.max()

# original image
plt.figure(1, figsize=(7,6))
plt.imshow(np.rot90(imgData), cmap='gray', vmin=vmin, vmax=256)
plt.tight_layout()
# segmented image
plt.figure(2, figsize=(7, 6))
plt.imshow(np.rot90(imgData_seg), cmap='gist_rainbow', vmin=vmin, vmax=vmax)
plt.tight_layout()

# %% [markdown]
# ##Plot the different classes
# While it's useful to view the predicted classes together, it can also help to see them plotted separately. Do the maps resemble known brain tissue distributions?

# %%
fig,axes = plt.subplots(nrows=k,ncols=1, figsize=(k*5,k*5))
axes = axes.flatten()
seg = defaultdict()
for i in range(k):
  seg[i] = np.ma.masked_where(imgData_seg == values[i], imgData_seg)
  axes[i].imshow(np.rot90(seg[i]), cmap='binary', vmin=0, vmax=1)
print("Number of clusters K = "+ str(k))
plt.tight_layout()
# Out:
# Number of clusters K = 4

# %% [markdown]
# #Expectation-maximisation for GMM segmentation
# A potentially more powerful approach is to fit a Gaussian Mixture Model (GMM) instead, that takes into the parameters of the latent distributions in the data.
# ##Select data and set parameters
# Choose which image to use as input (normal brain, noisy, very nosiy or bias).<br>
# Set the number of classes *k*, allocate space for arrays and for the priors, the maximum number of iterations and convergence tolerance level.<br>
# You can try varying the maximum number of iterations (*maxIterations*) or tolerance level and see how this affects results.

# %%
# Select input data
imgData = brainData

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 200
numClass = 4
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
np.random.seed(37) # set seed for reproducibility
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Define array for MRF that matches image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# ##Run Iterative EM process
# Try running with and without the MRF, see how this changes the results, particularly when varying the input file (i.e., brainData vs. noiseData). To do this, comment out the appropriate line in the Expectation code block.
#
# *Remember to reset the parameters above, each time you run the EM algorithm.*

# %%
# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        classProb[:, :, classIndex] = (gaussPdf + 0.0000001) * MRF[:,:,classIndex] # comment out this line to remove the MRF term
        # classProb[:, :, classIndex] = (gaussPdf + 0.0000001) # include this line to remove the MRF term
        classProbSum[:, :] = classProbSum[:, :] + classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] / classProbSum[:, :]

    # Maximization
    print("Iteration #" + str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex)) # comment out this line to remove the MRF term
        print("Class index " + str(classIndex) + ": mean = " + str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik) + "\n" + u'\u2015' * 60)

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [207.30229443], variance = [2054.14509264]
# Class index 1: mean = [115.04105334], variance = [234.40010081]
# Class index 2: mean = [19.37073042], variance = [613.24811724]
# Class index 3: mean = [154.54110696], variance = [177.84222437]
# Loglikelihood change = -999783482.681335
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #2
# Class index 0: mean = [198.95629295], variance = [840.15667192]
# Class index 1: mean = [112.93382685], variance = [186.32648137]
# Class index 2: mean = [18.33754567], variance = [560.19922997]
# Class index 3: mean = [156.48450921], variance = [84.05209174]
# Loglikelihood change = -13937.375549800432
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #3
# Class index 0: mean = [195.57474167], variance = [789.48660714]
# Class index 1: mean = [113.14996711], variance = [202.89558141]
# Class index 2: mean = [17.9465975], variance = [538.62600464]
# Class index 3: mean = [157.04790971], variance = [60.76270975]
# Loglikelihood change = -11136.579813433636
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #4
# Class index 0: mean = [191.61119444], variance = [793.28859341]
# Class index 1: mean = [113.38368242], variance = [228.22206507]
# Class index 2: mean = [17.57334275], variance = [520.16470588]
# Class index 3: mean = [157.43501566], variance = [48.44439872]
# Loglikelihood change = -1612.6128605485137
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #5
# Class index 0: mean = [188.46465993], variance = [833.10227658]
# Class index 1: mean = [113.58301029], variance = [253.62231179]
# Class index 2: mean = [17.21837326], variance = [502.70442629]
# Class index 3: mean = [157.82585518], variance = [39.69837211]
# Loglikelihood change = -1116.440941058594
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #6
# Class index 0: mean = [185.88336161], variance = [882.10969796]
# Class index 1: mean = [113.74602354], variance = [278.37977617]
# Class index 2: mean = [16.89008155], variance = [487.01578131]
# Class index 3: mean = [158.18193863], variance = [32.7935116]
# Loglikelihood change = -939.5749089886667
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #7
# Class index 0: mean = [183.82111078], variance = [921.89347543]
# Class index 1: mean = [113.90906411], variance = [302.1388222]
# Class index 2: mean = [16.59290265], variance = [473.00459722]
# Class index 3: mean = [158.50286143], variance = [27.06036258]
# Loglikelihood change = -811.0426859843428
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #8
# Class index 0: mean = [182.17007587], variance = [954.69822003]
# Class index 1: mean = [114.07770859], variance = [325.15132536]
# Class index 2: mean = [16.32067943], variance = [460.29374805]
# Class index 3: mean = [158.77465618], variance = [22.52663638]
# Loglikelihood change = -752.9200874999515
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #9
# Class index 0: mean = [180.81931252], variance = [977.59099253]
# Class index 1: mean = [114.22537512], variance = [346.92978189]
# Class index 2: mean = [16.0737585], variance = [448.94165634]
# Class index 3: mean = [159.00534529], variance = [19.11527148]
# Loglikelihood change = -683.3730426396942
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #10
# Class index 0: mean = [179.65900862], variance = [1003.45205506]
# Class index 1: mean = [114.34903239], variance = [367.51028235]
# Class index 2: mean = [15.84527735], variance = [438.571969]
# Class index 3: mean = [159.20397568], variance = [16.57913977]
# Loglikelihood change = -565.6852135537192
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #11
# Class index 0: mean = [178.74795117], variance = [1025.53969192]
# Class index 1: mean = [114.45029901], variance = [386.37159646]
# Class index 2: mean = [15.63654881], variance = [429.15679242]
# Class index 3: mean = [159.3701292], variance = [14.58773659]
# Loglikelihood change = -479.9833311730181
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #12
# Class index 0: mean = [177.95876728], variance = [1048.17626341]
# Class index 1: mean = [114.53066853], variance = [403.76809896]
# Class index 2: mean = [15.44546344], variance = [420.63443535]
# Class index 3: mean = [159.50516944], variance = [13.02766445]
# Loglikelihood change = -385.3959472864517
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #13
# Class index 0: mean = [177.30566744], variance = [1067.78594783]
# Class index 1: mean = [114.57687073], variance = [420.29404238]
# Class index 2: mean = [15.26553478], variance = [412.76739061]
# Class index 3: mean = [159.6146979], variance = [11.9142546]
# Loglikelihood change = -310.6434401231527
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #14
# Class index 0: mean = [176.74340642], variance = [1090.90094204]
# Class index 1: mean = [114.5969492], variance = [435.98292773]
# Class index 2: mean = [15.09387131], variance = [405.33220015]
# Class index 3: mean = [159.7000142], variance = [11.1207345]
# Loglikelihood change = -269.2634048881009
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #15
# Class index 0: mean = [176.28675436], variance = [1111.26244704]
# Class index 1: mean = [114.58667025], variance = [450.50911566]
# Class index 2: mean = [14.92954419], variance = [398.24557814]
# Class index 3: mean = [159.76827302], variance = [10.512694]
# Loglikelihood change = -239.91750460545882
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #16
# Class index 0: mean = [175.87098265], variance = [1132.42306232]
# Class index 1: mean = [114.54425182], variance = [464.41118145]
# Class index 2: mean = [14.76466735], variance = [391.15475585]
# Class index 3: mean = [159.82352067], variance = [10.03823759]
# Loglikelihood change = -202.58521810400998
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #17
# Class index 0: mean = [175.49654676], variance = [1151.10111169]
# Class index 1: mean = [114.47394301], variance = [477.69114403]
# Class index 2: mean = [14.60085052], variance = [384.17122038]
# Class index 3: mean = [159.86922291], variance = [9.65445499]
# Loglikelihood change = -189.7161421792989
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Converged after 17 iterations

# %% [markdown]
# ###Save segmented images as separate PNG files
# Use the cell below to save to Google drive

# %%
for classIndex in range(0, numClass):
    print("Saving "+"seg"+str(classIndex)+".png")
    save_file(classProb[ : ,: ,classIndex] * 255, str(fileLocation)+"seg"+str(classIndex)+".png")
# Out:
# Saving seg0.png
# Saving seg1.png
# Saving seg2.png
# Saving seg3.png

# %% [markdown]
# ###Display images
# Take a look at the results. How do they compare to the K-means output? What's the impact of varying K? What difference does the MRF constraint make?

# %%
for seg in range(numClass):
    print('Class number '+str(seg))
    disp_jpg('seg'+str(seg)+'.png')
# Out:
# Class number 0
# <PIL.Image.Image image mode=L size=217x181>
# Class number 1
# <PIL.Image.Image image mode=L size=217x181>
# Class number 2
# <PIL.Image.Image image mode=L size=217x181>
# Class number 3
# <PIL.Image.Image image mode=L size=217x181>

# %%
# !ls IPMI-teaching
# Out:
# brain_bias.png	 CSF_prior.png	     README.md	seg2.png	     verynoisy.png
# brain_noise.png  GM_prior.png	     seg0.png	seg3.png	     WM_prior.png
# brain.png	 NonBrain_prior.png  seg1.png	T1w_standard.nii.gz

# %%
disp_jpg('seg0.png')
# Out:
# <PIL.Image.Image image mode=L size=217x181>

# %% [markdown]
# ###Download images
# To get the results you can download the image PNG files to your local machine. Uncomment the code cell below:

# %%
# from google.colab import files
# files.download('seg0.png')

# %% [markdown]
# ##Add anatomical priors to the algorithm
# The priors provide spatial probabilities about the likely tissue class in each pixel. Crucially, these are in the same anatomical space as the input data.

# %% [markdown]
# ###Display image priors

# %%
print('Grey matter prior')
disp_jpg('GM_prior.png')
print('White matter prior')
disp_jpg('WM_prior.png')
print('CSF prior')
disp_jpg('CSF_prior.png')
print('Non brain prior')
disp_jpg('NonBrain_prior.png')
# Out:
# Grey matter prior
# <PIL.Image.Image image mode=L size=217x181>
# White matter prior
# <PIL.Image.Image image mode=L size=217x181>
# CSF prior
# <PIL.Image.Image image mode=L size=217x181>
# Non brain prior
# <PIL.Image.Image image mode=L size=217x181>

# %% [markdown]
# Read in and convert to arrays

# %%
print("Loading data")
GM_Prior = read_file(fileLocation+'GM_prior.png')
WM_Prior = read_file(fileLocation+'WM_prior.png')
CSF_Prior = read_file(fileLocation+'CSF_prior.png')
Other_Prior = read_file(fileLocation+'NonBrain_prior.png')
# Out:
# Loading data

# %% [markdown]
# ###Edit model parameters to incorporate priors
# Try changing the input data to see how this impacts the results. Note that the number of classes (K) must be the same as the number of different prior maps, so here K must = 4.

# %%
# Select input data
imgData = brainData

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 20
numClass = 4
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Allocate space for the priors
classPrior=np.ndarray([np.size(imgData,0),np.size(imgData,1),4])
classPrior[:, :, 0] = GM_Prior/255
classPrior[:, :, 1] = WM_Prior/255
classPrior[:, :, 2] = CSF_Prior/255
classPrior[:, :, 3] = Other_Prior/255

for classIndex in range(0, numClass):
    pik = classPrior[:, :, classIndex]
    mean[classIndex] = np.sum(pik * imgData) / np.sum(pik)
    var[classIndex] = np.sum(pik * ((imgData - mean[classIndex]) ** 2)) / np.sum(pik)

# Define MRF array to match image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# ###Re-run EM process
# This time the class probabilities are multiplied by the probability value from the anatomical prior at each pixel.

# %%
# Conditional to stop process if numClass != 4
if numClass != 4:
    print('no')
    sys.exit("numClass must == 4")

# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        classProb[:, :, classIndex] = (gaussPdf+0.0000001) * classPrior[:, :, classIndex] * MRF[:,:,classIndex]
        classProbSum[:, :] = classProbSum[:, :]+classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] /classProbSum[:, :]

    # Maximization
    print("Iteration #"+str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex))
        print("Class index "+ str(classIndex) + ": mean = "+str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik) + "\n" + u'\u2015' * 60)

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [119.08280602], variance = [549.04923411]
# Class index 1: mean = [152.38237367], variance = [211.54946565]
# Class index 2: mean = [92.38972156], variance = [1783.77090033]
# Class index 3: mean = [31.84920567], variance = [2321.1404959]
# Loglikelihood change = -999803440.1502862
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #2
# Class index 0: mean = [117.12908121], variance = [213.21799132]
# Class index 1: mean = [155.31266215], variance = [104.23148353]
# Class index 2: mean = [74.23591897], variance = [882.59985544]
# Class index 3: mean = [34.21546261], variance = [2530.54007746]
# Loglikelihood change = 47101.72113573656
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #3
# Class index 0: mean = [117.72201553], variance = [179.3609384]
# Class index 1: mean = [156.30468065], variance = [75.10943858]
# Class index 2: mean = [70.34792359], variance = [572.3106755]
# Class index 3: mean = [34.6323791], variance = [2581.61128375]
# Loglikelihood change = -33300.281819237105
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #4
# Class index 0: mean = [118.41758083], variance = [167.5741735]
# Class index 1: mean = [156.97970263], variance = [58.36866666]
# Class index 2: mean = [69.43860471], variance = [528.46655414]
# Class index 3: mean = [34.66337433], variance = [2582.60451563]
# Loglikelihood change = -3967.0943096595
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #5
# Class index 0: mean = [119.07280927], variance = [160.85728894]
# Class index 1: mean = [157.5278695], variance = [45.86860551]
# Class index 2: mean = [68.9810049], variance = [507.2382626]
# Class index 3: mean = [34.68798331], variance = [2583.59073515]
# Loglikelihood change = -887.5462778347137
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #6
# Class index 0: mean = [119.66444781], variance = [158.1281211]
# Class index 1: mean = [157.97680785], variance = [36.3855315]
# Class index 2: mean = [68.6913919], variance = [491.48374129]
# Class index 3: mean = [34.70263149], variance = [2584.40413126]
# Loglikelihood change = -574.4117101160518
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #7
# Class index 0: mean = [120.22202142], variance = [158.7931154]
# Class index 1: mean = [158.34491654], variance = [29.63723242]
# Class index 2: mean = [68.53915063], variance = [483.66745487]
# Class index 3: mean = [34.71269497], variance = [2585.10651275]
# Loglikelihood change = -450.2172202930087
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #8
# Class index 0: mean = [120.73595313], variance = [161.83137279]
# Class index 1: mean = [158.66375022], variance = [24.30217028]
# Class index 2: mean = [68.42599361], variance = [478.09441776]
# Class index 3: mean = [34.71940781], variance = [2585.65940863]
# Loglikelihood change = -338.5409281136526
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #9
# Class index 0: mean = [121.19567656], variance = [165.89266706]
# Class index 1: mean = [158.91677159], variance = [20.52973204]
# Class index 2: mean = [68.28879108], variance = [471.96656309]
# Class index 3: mean = [34.72371168], variance = [2586.11902222]
# Loglikelihood change = -325.0939249336079
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #10
# Class index 0: mean = [121.58812861], variance = [170.42485189]
# Class index 1: mean = [159.11035723], variance = [17.95176277]
# Class index 2: mean = [68.15873319], variance = [466.68770652]
# Class index 3: mean = [34.72735212], variance = [2586.48217888]
# Loglikelihood change = -240.8661479105358
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #11
# Class index 0: mean = [121.91813474], variance = [175.04433489]
# Class index 1: mean = [159.26448381], variance = [16.04797837]
# Class index 2: mean = [68.04931213], variance = [462.63983214]
# Class index 3: mean = [34.72970861], variance = [2586.77983951]
# Loglikelihood change = -166.65741012708168
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Converged after 11 iterations

# %% [markdown]
# Use the cell below to save the files to Google drive

# %%
for classIndex in range(0, numClass):
    print("Saving "+"prior_seg"+str(classIndex)+".png")
    save_file(classProb[ : ,: ,classIndex] * 255, str(fileLocation)+"prior_seg"+str(classIndex)+".png")
# Out:
# Saving prior_seg0.png
# Saving prior_seg1.png
# Saving prior_seg2.png
# Saving prior_seg3.png

# %% [markdown]
# Display the images. How do they compare to the previous versions without anatomical priors?

# %%
disp_jpg('prior_seg0.png')
disp_jpg('prior_seg1.png')
disp_jpg('prior_seg2.png')
disp_jpg('prior_seg3.png')
# Out:
# <PIL.Image.Image image mode=L size=217x181>
# <PIL.Image.Image image mode=L size=217x181>
# <PIL.Image.Image image mode=L size=217x181>
# <PIL.Image.Image image mode=L size=217x181>

# %% [markdown]
# ---
# #Working with Nifti files
# The following is a brief tutorial on how to load, view and manipulate Nifti (.nii) files in Python. This example takes a slice and run it through the EM procedure using GMMs to segment brain tissue as above. For this example to work well, you need to select an axial slice similar to the anatomical priors.

# %% [markdown]
# ##Define function to read in 3D brain image
# Uses nibabel library to read nifti files

# %%
t1_nii = fileLocation+'T1w_standard.nii.gz'
print(t1_nii)
img = nib.load(t1_nii)
img_array = img.get_fdata() # convert from nifti object to array
# Out:
# ./IPMI-teaching/T1w_standard.nii.gz

# %% [markdown]
# ##Plot image slice

# %%
sliceNumber = 110
plt.imshow(np.rot90(img_array[:, :, sliceNumber]), origin="upper", cmap="gray")
plt.axis('off')
plt.tight_layout()

# %% [markdown]
# Histograms for this slice

# %%
plot_histogram(img_array[:, :, sliceNumber], 'Slice intensity')

# %% [markdown]
# Density plots for multiple slices. Notice that although the plots are generally similar, particularly in that they contain a lot of zeroes (i.e., background pixels), devising a general threshold to distinguish other the intensities in GM, WM and CSF  would not be possible.

# %%
plt.figure(figsize=(8,4))
sns.kdeplot(np.concatenate(img_array[:, :, 8]), color = 'red', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 50]), color = 'blue', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 75]), color = 'green', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 105]), color = 'purple', bw_method=0.05)
sns.kdeplot(np.concatenate(img_array[:, :, 120]), color = 'orange', bw_method=0.05)
plt.tight_layout()

# %% [markdown]
# ###Function for plotting multiple slices

# %%
def plot_slices(slices):
  fig, axes = plt.subplots(1, len(slices), figsize=(16,10))
  for i, slice in enumerate(slices):
    axes[i].imshow(slice.T, cmap="gray", origin="lower")

slice_1 = img_array[:, :, 65]
slice_2 = img_array[:, :, 75]
slice_3 = img_array[:, :, 85]
slice_4 = img_array[:, :, 95]
plot_slices([slice_1, slice_2,slice_3,slice_4])

# %% [markdown]
# ##Save slice as PNG image file

# %%
sliceNumber=84
save_file(img_array[:, :, sliceNumber] * 255, str(fileLocation)+"slice_"+str(sliceNumber)+".png")
disp_jpg("slice_"+str(sliceNumber)+".png")
# Out:
# <PIL.Image.Image image mode=L size=218x182>

# %% [markdown]
# ## Select a slice and run the segmentation
# Try with and without anatomical priors. Remember this is just in 2D, so be mindful of which slice you select.
# *You'll need to shave off 1 row in the x and y dimensions to fit this brain to the priors. This can be done by indexing the array.*

# %%
img_array2 = img_array[0:181,0:217,1:182]
plt.imshow(img_array2[:, :, sliceNumber], cmap="gray")
slice = img_array2[:,:,sliceNumber]

# %% [markdown]
# Check the dimensions are now correct

# %%
slice.shape
# Out:
# (181, 217)

# %% [markdown]
# **Set parameters**<br>
# Re-run prior to each EM

# %%
# Select input data
imgData = slice

# Parameters
didNotConverge = 1
iteration = 0
maxIterations = 20
numClass = 4
beta = 2
logLik = int(-10e8)
oldLogLik = int(-10e8)
tolerance = 200

# Initialise mean and variances
mean = np.random.rand(numClass,1)*256;
var = (np.random.rand(numClass,1)*10)+200;

# Allocate space for the posteriors
classProb = np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
classProbSum = np.ndarray([np.size(imgData,0),np.size(imgData,1)])

# Allocate space for the priors
classPrior=np.ndarray([np.size(imgData,0),np.size(imgData,1),4])
classPrior[:, :, 0] = GM_Prior/255
classPrior[:, :, 1] = WM_Prior/255
classPrior[:, :, 2] = CSF_Prior/255
classPrior[:, :, 3] = Other_Prior/255

for classIndex in range(0, numClass):
    pik = classPrior[:, :, classIndex]
    mean[classIndex] = np.sum(pik * imgData) / np.sum(pik)
    var[classIndex] = np.sum(pik * ((imgData - mean[classIndex]) ** 2)) / np.sum(pik)

# Define MRF array to match image dimensions
MRF=np.ndarray([np.size(imgData,0),np.size(imgData,1),numClass])
MRF[:,:,:]=1

# %% [markdown]
# **Run EM**

# %%
# Iterative process
while didNotConverge:
    iteration=iteration+1

    # Expectation
    classProbSum[:, :] = 0;
    for classIndex in range(0, numClass):
        gaussPdf = (1/np.sqrt(var[classIndex]*2*np.pi))*np.exp(-0.5* (imgData-mean[classIndex])**2/var[classIndex])
        classProb[:, :, classIndex] = (gaussPdf+0.0000001)*classPrior[:, :, classIndex]*MRF[:,:,classIndex]
        classProbSum[:, :] = classProbSum[:, :]+classProb[:, :, classIndex]

    # Normalise posterior
    for classIndex in range(0, numClass):
        classProb[:, :, classIndex] = classProb[:, :, classIndex] /classProbSum[:, :]

    # Maximization
    print("Iteration #"+str(iteration))
    for classIndex in range(0, numClass):
        pik = classProb[:, :, classIndex]
        mean[classIndex] = np.sum(pik*imgData) / np.sum(pik)
        var[classIndex] = np.sum(pik*((imgData - mean[classIndex])**2)) / np.sum(pik)
        MRF[:,:,classIndex] = np.exp(-beta * Umrf(classProb,classIndex))
        print("Class index "+ str(classIndex) + ": mean = "+str(mean[classIndex]) + ", variance = " + str(var[classIndex]))

    # Calculate log likelihood
    oldLogLik = logLik
    logLik = np.sum(np.log(classProbSum))
    diffLogLik = oldLogLik - logLik
    print("Loglikelihood change = " + str(diffLogLik) + "\n" + u'\u2015' * 60)

    if abs(diffLogLik)<=tolerance:
      didNotConverge=0
      print("Converged after " + str(iteration) + " iterations")

    if iteration>=maxIterations:
        didNotConverge=0
        print("Reached "+ str(maxIterations) + " iterations (the maximum) and did not coverge")
# Out:
# Iteration #1
# Class index 0: mean = [188.7035156], variance = [2653.35556441]
# Class index 1: mean = [235.4925997], variance = [2000.42634414]
# Class index 2: mean = [182.05248384], variance = [4812.98969961]
# Class index 3: mean = [65.19772297], variance = [10085.33248546]
# Loglikelihood change = -999774954.4409995
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #2
# Class index 0: mean = [179.5112581], variance = [1929.55068009]
# Class index 1: mean = [241.67166508], variance = [1729.80169012]
# Class index 2: mean = [169.65531088], variance = [4033.22805137]
# Class index 3: mean = [69.17471899], variance = [10450.57504993]
# Loglikelihood change = 62462.0643751692
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #3
# Class index 0: mean = [177.33700445], variance = [1768.98567113]
# Class index 1: mean = [242.71092512], variance = [1685.13755006]
# Class index 2: mean = [170.00380744], variance = [4158.80249377]
# Class index 3: mean = [69.37743256], variance = [10449.74666526]
# Loglikelihood change = -35998.17087383021
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #4
# Class index 0: mean = [176.28214905], variance = [1706.66705311]
# Class index 1: mean = [243.05677959], variance = [1672.72241405]
# Class index 2: mean = [170.85737666], variance = [4190.05130965]
# Class index 3: mean = [69.37917384], variance = [10452.56662261]
# Loglikelihood change = -7618.869462375733
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #5
# Class index 0: mean = [175.53827582], variance = [1657.21745245]
# Class index 1: mean = [243.36802325], variance = [1660.1725884]
# Class index 2: mean = [171.29086636], variance = [4202.86937916]
# Class index 3: mean = [69.37387414], variance = [10454.37648537]
# Loglikelihood change = -1376.6072175514128
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #6
# Class index 0: mean = [174.96727641], variance = [1619.10619789]
# Class index 1: mean = [243.64156271], variance = [1648.74081767]
# Class index 2: mean = [171.63994201], variance = [4210.57759222]
# Class index 3: mean = [69.36533116], variance = [10455.75007523]
# Loglikelihood change = -434.2919493803638
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #7
# Class index 0: mean = [174.54654612], variance = [1590.9923047]
# Class index 1: mean = [243.86769234], variance = [1637.65192413]
# Class index 2: mean = [171.87999833], variance = [4214.99041766]
# Class index 3: mean = [69.35631205], variance = [10456.37362459]
# Loglikelihood change = -249.9311224325793
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Iteration #8
# Class index 0: mean = [174.17110465], variance = [1568.11421743]
# Class index 1: mean = [244.06652113], variance = [1627.71200307]
# Class index 2: mean = [172.15030667], variance = [4212.85010176]
# Class index 3: mean = [69.34468921], variance = [10456.75420568]
# Loglikelihood change = -174.76307912362972
# ――――――――――――――――――――――――――――――――――――――――――――――――――――――――――――
# Converged after 8 iterations

# %% [markdown]
# Save images

# %%
for classIndex in range(0, numClass):
    print("Saving "+"slice_"+str(sliceNumber)+"_seg"+str(classIndex)+".png")
    save_file(classProb[ : ,: ,classIndex] * 255, str(fileLocation)+"slice_"+str(sliceNumber)+"_seg"+str(classIndex)+".png")
# Out:
# Saving slice_84_seg0.png
# Saving slice_84_seg1.png
# Saving slice_84_seg2.png
# Saving slice_84_seg3.png

# %% [markdown]
# Display images

# %%
import glob
for slice_seg in glob.glob('slice_'+str(sliceNumber)+'*seg*.png'):
    print(str(slice_seg))
    disp_jpg(slice_seg)
